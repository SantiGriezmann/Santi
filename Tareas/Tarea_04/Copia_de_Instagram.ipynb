# %%
import pandas as pd
tiempo_de_uso_Instagram = pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Tiempo de uso instagram por favor.csv")
tiempo_de_uso_Instagram
# Out:
#     Fecha  Minutos
# 0  02-oct       31
# 1  03-oct       16
# 2  04-oct       39
# 3  05-oct       34
# 4  06-oct       30
# 5  07-oct       47
# 6  08-oct       15
# 7  09-oct       39
# 8  10-oct       41
# 9  11-oct        4

# %%
import pandas as pd
nRowsRead = 10 # specify 'None' if want to read whole file
# Hp1 may have more rows in reality, but we are only loading/previewing the first 1000 rows
df1 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Tiempo de uso instagram por favor.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'Tiempo de uso instagram por favor.csv'
nRow, nCol = df1.shape
print(f'There are {10} rows and {2} columns')
# Out:
# There are 10 rows and 2 columns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1.head(5)
# Out:
#     Fecha  Minutos
# 0  02-oct       31
# 1  03-oct       16
# 2  04-oct       39
# 3  05-oct       34
# 4  06-oct       30

# %%
print(df1.columns)
# Out:
# Index(['Fecha', 'Minutos'], dtype='object')

# %%
cat_totals = df1.groupby("Fecha")["Minutos"].sum().sort_values()
cat_totals
# Out:
# Fecha
# 11-oct     4
# 08-oct    15
# 03-oct    16
# 06-oct    30
# 02-oct    31
# 05-oct    34
# 04-oct    39
# 09-oct    39
# 10-oct    41
# 07-oct    47
# Name: Minutos, dtype: int64

# %%
ax = cat_totals.plot(kind="barh", fontsize=4)
ax.set_xlabel('Minutos')
ax.set_ylabel('Fecha')
ax.set_title('Tiempo de uso Instagram en una semana')
ax
# Out:
# <Axes: title={'center': 'Tiempo de uso Instagram en una semana'}, xlabel='Minutos', ylabel='Fecha'>
